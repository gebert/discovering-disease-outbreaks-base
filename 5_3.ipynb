# %% [markdown]
# # Report
#
# There are two cluster in the US and four cluster in the rest of the world with a potential Zika outbreak. One cluster in Europe has a potential outbreak of mad cow disease that is not taken into further account in this report.

# %%
from IPython.display import Image

Image('us_disease_cluster_m.png')

# %%
Image('rdw_disease_cluster_m.png')

# %%
Image('final_outbreak_map.png')

# %% [markdown]
# Overview of all headlines related to Zika. Not all headlines indicate a valid case but the overall amount in each cluster may indicate an epidemic outbreak.
#
# * Mid-South United States (72) and Central America (39): 111 headlines
# * East Asia: 39 headlines
# * Eastern South America: 18 headlines
# * India: 8 headline
